# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'/Users/Nicole/Documents/CareerFoundry/Data Analytics Program/Achievement 4 Immersion/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
df = ords_prods_merge[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# <ipython-input-6-fe64de1169c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# Not enough data         953
# Name: price_range, dtype: int64

# %%
#this data set does not match the one that is in the example- the outlier still in the dataframe as per the below 99999.00 price

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# NaN                   21218535
# Low-range product     10126321
# Mid-range product       672525
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
# these numbers for value counts also do not add up as in the example.

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#    Unnamed: 0                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.rename(columns={'order_dow':'order_day_of_the_week'}, inplace=True)

# %%
ords_prods_merge['order_day_of_the_week'].value_counts(dropna=False)
# Out:
# 0    6209808
# 1    5665951
# 6    4500391
# 2    4217868
# 5    4209603
# 3    3844175
# 4    3787263
# Name: order_day_of_the_week, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_day_of_the_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day']= result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22437988
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %% [markdown]
# 4.7 Deriving New Variables Task

# %% [markdown]
# 2. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# check for busiest and slowes days of the week
ords_prods_merge['order_day_of_the_week'].value_counts(dropna=False)
# Out:
# 0    6209808
# 1    5665951
# 6    4500391
# 2    4217868
# 5    4209603
# 3    3844175
# 4    3787263
# Name: order_day_of_the_week, dtype: int64

# %%
# defining results for 2 busiest and 2 slowest days of the week
result = []

for value in ords_prods_merge['order_day_of_the_week']:
  if value == 0 and 1:
    result.append('Busiest days')
  elif value == 3 and 4:
    result.append('Slowest days')
  else:
    result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['Busiest_days'] = result

# %%
ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    22381076
# Busiest days       6209808
# Slowest days       3844175
# Name: Busiest_days, dtype: int64

# %% [markdown]
# 3. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# checking values of the new columns for accuracy
ords_prods_merge.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_the_week  \
# 0   2539329        1    prior             1                      2
# 1   2539329        1    prior             1                      2
# 2   2539329        1    prior             1                      2
# 3   2539329        1    prior             1                      2
# 4   2539329        1    prior             1                      2
# 5   2398795        1    prior             2                      3
# 6   2398795        1    prior             2                      3
# 7   2398795        1    prior             2                      3
# 8   2398795        1    prior             2                      3
# 9   2398795        1    prior             2                      3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# ...

# %% [markdown]
# my observations are that the two columns busiest day and busiest days could get confusing. I would have labeled it differently since they are so closely worded. I could see how this would give a larger range for busy or slow days since it is now changed though but also see how it would be good to keep both incase there is a difference and the company still would like to see the difference.

# %%
# checking the busiest hour of day
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764476
# 11    2738647
# 14    2691598
# 15    2664583
# 13    2663346
# 12    2620898
# 16    2537506
# 9     2456751
# 17    2089510
# 8     1719991
# 18    1637956
# 19    1259416
# 20     977049
# 7      891951
# 21     796379
# 22     634743
# 23     402621
# 6      290796
# 0      218951
# 1      115787
# 5       88064
# 2       69435
# 4       53284
# 3       51321
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_hour_of_day"]:
  if value == 10:
    result.append("Most Orders")
  elif value == 11:
    result.append("Most Orders")
  elif value == 14:
    result.append("Most Orders")    
  elif value == 15:
    result.append("Most Orders")
  elif value == 13:
    result.append("Most Orders")
  elif value == 12:
    result.append("Most Orders")
  elif value == 16:
    result.append("Most Orders")
  elif value == 9:
    result.append("Most Orders")
  elif value == 3:
    result.append("Fewest Orders")
  elif value == 4:
    result.append("Fewest Orders")
  elif value == 2:
    result.append("Fewest Orders")
  elif value == 5:
    result.append("Fewest Orders")
  elif value == 1:
    result.append("Fewest Orders")
  elif value == 0:
    result.append("Fewest Orders")
  elif value == 6:
    result.append("Fewest Orders")
  elif value == 23:
    result.append("Fewest Orders")
  else:
    result.append("Average Orders")

# %%
result
# Out:
# ['Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
# ...

# %%
ords_prods_merge['busiest_period_of_day']=result

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_the_week  \
# 0   2539329        1    prior             1                      2
# 1   2539329        1    prior             1                      2
# 2   2539329        1    prior             1                      2
# 3   2539329        1    prior             1                      2
# 4   2539329        1    prior             1                      2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered  Unnamed: 0                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most Orders       21137805
# Average Orders    10006995
# Fewest Orders      1290259
# Name: busiest_period_of_day, dtype: int64

# %%
path = r'/Users/Nicole/Documents/CareerFoundry/Data Analytics Program/Achievement 4 Immersion/Instacart Basket Analysis'

# %%
ords_prods_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merged_new_variables.pkl'))
